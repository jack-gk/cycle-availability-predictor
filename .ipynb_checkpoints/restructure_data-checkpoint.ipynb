# %%
import json
import pandas as pd
import numpy as np
from pathlib import Path
from datetime import datetime

# %%
bronze_path = Path.cwd()/"data"/"bronze"
    
#file_name = "tfl-bikes-2026-07-24-H12-M45.json"


dataframes = []

for file in list(bronze_path.iterdir()):
    
    # if len(dataframes)>5:
    #     print("BREAK")
    #     break
        
    if file.stat().st_size == 0:
        print(f"Skipping empty file: {file.name}")
        continue
        
    if ((file.name[:10]+file.name[-5:])!="tfl-bikes-.json"):
        print(f"Formatting error using {file.name}")
        raise ValueError
        
    else:
        time = (file.name[10:-5])
        date_time = datetime.strptime(
            time,
            "%Y-%m-%d-H%H-M%M"
        )
        
    with open(file) as f:
        json_input = json.load(f)
    
    df = pd.json_normalize(json_input)
    df["date_time"] = date_time

    dataframes.append(df)

print(len(dataframes))
# Out:
# Skipping empty file: tfl-bikes-2026-07-24-H13-M45.json
# Skipping empty file: tfl-bikes-2026-07-24-H13-M50.json
# Skipping empty file: tfl-bikes-2026-07-24-H13-M55.json
# Skipping empty file: tfl-bikes-2026-07-24-H14-M15.json
# 1713

# %%
df = pd.concat(dataframes, ignore_index=True)

# %%
df_long = df.explode("additionalProperties",True)

# %%
properties = pd.json_normalize(
    df_long["additionalProperties"]
)

# %%
properties
# Out:
#                                                       $type     category  \
# 0         Tfl.Api.Presentation.Entities.AdditionalProper...  Description
# 1         Tfl.Api.Presentation.Entities.AdditionalProper...  Description
# 2         Tfl.Api.Presentation.Entities.AdditionalProper...  Description
# 3         Tfl.Api.Presentation.Entities.AdditionalProper...  Description
# 4         Tfl.Api.Presentation.Entities.AdditionalProper...  Description
# ...                                                     ...          ...
# 15033590  Tfl.Api.Presentation.Entities.AdditionalProper...  Description
# 15033591  Tfl.Api.Presentation.Entities.AdditionalProper...  Description
# 15033592  Tfl.Api.Presentation.Entities.AdditionalProper...  Description
# 15033593  Tfl.Api.Presentation.Entities.AdditionalProper...  Description
# 15033594  Tfl.Api.Presentation.Entities.AdditionalProper...  Description
#
#                       key sourceSystemKey          value  \
# 0            TerminalName      BikePoints         001023
# 1               Installed      BikePoints           true
# 2                  Locked      BikePoints          false
# 3             InstallDate      BikePoints  1278947280000
# 4             RemovalDate      BikePoints
# ...                   ...             ...            ...
# 15033590          NbBikes      BikePoints              1
# 15033591     NbEmptyDocks      BikePoints             15
# 15033592          NbDocks      BikePoints             16
# 15033593  NbStandardBikes      BikePoints              1
# 15033594         NbEBikes      BikePoints              0
#
#                           modified
# 0         2026-07-24T12:43:59.477Z
# 1         2026-07-24T12:43:59.477Z
# 2         2026-07-24T12:43:59.477Z
# 3         2026-07-24T12:43:59.477Z
# 4         2026-07-24T12:43:59.477Z
# ...                            ...
# 15033590  2026-07-30T10:30:52.107Z
# 15033591  2026-07-30T10:30:52.107Z
# 15033592  2026-07-30T10:30:52.107Z
# 15033593  2026-07-30T10:30:52.107Z
# 15033594  2026-07-30T10:30:52.107Z
#
# [15033595 rows x 6 columns]

# %%
df_long
# Out:
#                                                       $type              id  \
# 0         Tfl.Api.Presentation.Entities.Place, Tfl.Api.P...    BikePoints_1
# 1         Tfl.Api.Presentation.Entities.Place, Tfl.Api.P...    BikePoints_1
# 2         Tfl.Api.Presentation.Entities.Place, Tfl.Api.P...    BikePoints_1
# 3         Tfl.Api.Presentation.Entities.Place, Tfl.Api.P...    BikePoints_1
# 4         Tfl.Api.Presentation.Entities.Place, Tfl.Api.P...    BikePoints_1
# ...                                                     ...             ...
# 15033590  Tfl.Api.Presentation.Entities.Place, Tfl.Api.P...  BikePoints_403
# 15033591  Tfl.Api.Presentation.Entities.Place, Tfl.Api.P...  BikePoints_403
# 15033592  Tfl.Api.Presentation.Entities.Place, Tfl.Api.P...  BikePoints_403
# 15033593  Tfl.Api.Presentation.Entities.Place, Tfl.Api.P...  BikePoints_403
# 15033594  Tfl.Api.Presentation.Entities.Place, Tfl.Api.P...  BikePoints_403
#
#                             url                     commonName  placeType  \
# 0           /Place/BikePoints_1     River Street , Clerkenwell  BikePoint
# 1           /Place/BikePoints_1     River Street , Clerkenwell  BikePoint
# 2           /Place/BikePoints_1     River Street , Clerkenwell  BikePoint
# 3           /Place/BikePoints_1     River Street , Clerkenwell  BikePoint
# 4           /Place/BikePoints_1     River Street , Clerkenwell  BikePoint
# ...                         ...                            ...        ...
# 15033590  /Place/BikePoints_403  George Place Mews, Marylebone  BikePoint
# 15033591  /Place/BikePoints_403  George Place Mews, Marylebone  BikePoint
# 15033592  /Place/BikePoints_403  George Place Mews, Marylebone  BikePoint
# 15033593  /Place/BikePoints_403  George Place Mews, Marylebone  BikePoint
# 15033594  /Place/BikePoints_403  George Place Mews, Marylebone  BikePoint
#
#                                        additionalProperties children  \
# 0         {'$type': 'Tfl.Api.Presentation.Entities.Addit...       []
# 1         {'$type': 'Tfl.Api.Presentation.Entities.Addit...       []
# 2         {'$type': 'Tfl.Api.Presentation.Entities.Addit...       []
# 3         {'$type': 'Tfl.Api.Presentation.Entities.Addit...       []
# 4         {'$type': 'Tfl.Api.Presentation.Entities.Addit...       []
# ...                                                     ...      ...
# 15033590  {'$type': 'Tfl.Api.Presentation.Entities.Addit...       []
# 15033591  {'$type': 'Tfl.Api.Presentation.Entities.Addit...       []
# 15033592  {'$type': 'Tfl.Api.Presentation.Entities.Addit...       []
# 15033593  {'$type': 'Tfl.Api.Presentation.Entities.Addit...       []
# 15033594  {'$type': 'Tfl.Api.Presentation.Entities.Addit...       []
#
#          childrenUrls        lat       lon           date_time
# 0                  []  51.529163 -0.109970 2026-07-24 12:45:00
# 1                  []  51.529163 -0.109970 2026-07-24 12:45:00
# 2                  []  51.529163 -0.109970 2026-07-24 12:45:00
# 3                  []  51.529163 -0.109970 2026-07-24 12:45:00
# 4                  []  51.529163 -0.109970 2026-07-24 12:45:00
# ...               ...        ...       ...                 ...
# 15033590           []  51.516892 -0.158249 2026-07-30 11:45:00
# 15033591           []  51.516892 -0.158249 2026-07-30 11:45:00
# 15033592           []  51.516892 -0.158249 2026-07-30 11:45:00
# 15033593           []  51.516892 -0.158249 2026-07-30 11:45:00
# 15033594           []  51.516892 -0.158249 2026-07-30 11:45:00
#
# [15033595 rows x 11 columns]

# %%
dfx = pd.concat(
    [
        df_long[["id", "date_time"]],
        properties
    ],
    axis=1
)

# %%
dfx_filtered = dfx[["id", "date_time", "key", "value"]]
dfx_filtered
# Out:
#                       id           date_time              key          value
# 0           BikePoints_1 2026-07-24 12:45:00     TerminalName         001023
# 1           BikePoints_1 2026-07-24 12:45:00        Installed           true
# 2           BikePoints_1 2026-07-24 12:45:00           Locked          false
# 3           BikePoints_1 2026-07-24 12:45:00      InstallDate  1278947280000
# 4           BikePoints_1 2026-07-24 12:45:00      RemovalDate
# ...                  ...                 ...              ...            ...
# 15033590  BikePoints_403 2026-07-30 11:45:00          NbBikes              1
# 15033591  BikePoints_403 2026-07-30 11:45:00     NbEmptyDocks             15
# 15033592  BikePoints_403 2026-07-30 11:45:00          NbDocks             16
# 15033593  BikePoints_403 2026-07-30 11:45:00  NbStandardBikes              1
# 15033594  BikePoints_403 2026-07-30 11:45:00         NbEBikes              0
#
# [15033595 rows x 4 columns]

# %%
dfx_filtered["key"].unique()
# Out:
# array(['TerminalName', 'Installed', 'Locked', 'InstallDate',
#        'RemovalDate', 'Temporary', 'NbBikes', 'NbEmptyDocks', 'NbDocks',
#        'NbStandardBikes', 'NbEBikes', 'LastUpdated', nan], dtype=object)

# %%
wanted = dfx_filtered["key"].unique()[6:11]

# %%
dfx_filtered
# Out:
#                       id           date_time              key          value
# 0           BikePoints_1 2026-07-24 12:45:00     TerminalName         001023
# 1           BikePoints_1 2026-07-24 12:45:00        Installed           true
# 2           BikePoints_1 2026-07-24 12:45:00           Locked          false
# 3           BikePoints_1 2026-07-24 12:45:00      InstallDate  1278947280000
# 4           BikePoints_1 2026-07-24 12:45:00      RemovalDate
# ...                  ...                 ...              ...            ...
# 15033590  BikePoints_403 2026-07-30 11:45:00          NbBikes              1
# 15033591  BikePoints_403 2026-07-30 11:45:00     NbEmptyDocks             15
# 15033592  BikePoints_403 2026-07-30 11:45:00          NbDocks             16
# 15033593  BikePoints_403 2026-07-30 11:45:00  NbStandardBikes              1
# 15033594  BikePoints_403 2026-07-30 11:45:00         NbEBikes              0
#
# [15033595 rows x 4 columns]

# %%
mask = dfx_filtered["key"].isin(wanted)

wanted_rows = dfx_filtered[mask]

wanted_rows#[["id", "key", "value"]]
# Out:
#                       id           date_time              key value
# 6           BikePoints_1 2026-07-24 12:45:00          NbBikes     2
# 7           BikePoints_1 2026-07-24 12:45:00     NbEmptyDocks    16
# 8           BikePoints_1 2026-07-24 12:45:00          NbDocks    19
# 9           BikePoints_1 2026-07-24 12:45:00  NbStandardBikes     1
# 10          BikePoints_1 2026-07-24 12:45:00         NbEBikes     1
# ...                  ...                 ...              ...   ...
# 15033590  BikePoints_403 2026-07-30 11:45:00          NbBikes     1
# 15033591  BikePoints_403 2026-07-30 11:45:00     NbEmptyDocks    15
# 15033592  BikePoints_403 2026-07-30 11:45:00          NbDocks    16
# 15033593  BikePoints_403 2026-07-30 11:45:00  NbStandardBikes     1
# 15033594  BikePoints_403 2026-07-30 11:45:00         NbEBikes     0
#
# [6833450 rows x 4 columns]

# %%
wanted_rows.columns
# Out:
# Index(['id', 'date_time', 'key', 'value'], dtype='object')

# %%
df_pivot = dfx_filtered.pivot(index=["id", "date_time"], columns="key", values="value")
wanted_columns = ['NbBikes', 'NbEBikes', 'NbStandardBikes', 'NbDocks', 'NbEmptyDocks']

new_df = df_pivot.loc[:, wanted_columns].copy()

new_df.dtypes

new_df = new_df.astype("Int64")

new_df.head(10)
# Out:
# key                               NbBikes  NbEBikes  NbStandardBikes  NbDocks  \
# id           date_time
# BikePoints_1 2026-07-24 12:45:00        2         1                1       19
#              2026-07-24 12:50:00        3         2                1       19
#              2026-07-24 12:55:00        3         2                1       19
#              2026-07-24 13:00:00        3         2                1       19
#              2026-07-24 13:05:00        3         2                1       19
#              2026-07-24 13:10:00        3         2                1       19
#              2026-07-24 13:15:00        3         2                1       19
#              2026-07-24 13:20:00        3         2                1       19
#              2026-07-24 13:25:00        3         2                1       19
#              2026-07-24 13:30:00        3         2                1       19
#
# key                               NbEmptyDocks
# id           date_time
# BikePoints_1 2026-07-24 12:45:00            16
#              2026-07-24 12:50:00            16
#              2026-07-24 12:55:00            16
#              2026-07-24 13:00:00            16
#              2026-07-24 13:05:00            16
#              2026-07-24 13:10:00            16
#              2026-07-24 13:15:00            16
#              2026-07-24 13:20:00            16
#              2026-07-24 13:25:00            16
#              2026-07-24 13:30:00            16

# %%
# OUTPUT
# 

output_path = Path.cwd() / "data" / "silver" / "tfl-bike-data.xlsx"

output_path.parent.mkdir(parents=True, exist_ok=True)



sample = new_df.head(500000)

sample.reset_index().to_excel(
    output_path,
    index=False
)

print(f"Saved to: {output_path}")
# Out:
# Saved to: C:\Users\jaack\Desktop\cycle-availability-predictor\data\silver\tfl-bike-data.xlsx
